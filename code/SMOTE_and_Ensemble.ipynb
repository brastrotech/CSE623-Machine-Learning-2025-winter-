# %%
import utils as u
import pickle as pkl
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier   
import seaborn as sns 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score
import matplotlib.pyplot as plt
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %% [markdown]
# # Without SMOTE

# %% [markdown]
# # T_eff

# %%
file_name = 'data_output_teff.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

results_data = {}
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
#Trial code 
k = 230
clf = KNeighborsClassifier(n_neighbors = k, weights='distance') 
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=230, weights='distance')

# %%
#Trial code 
training_score = clf.score(X_train, y_train) 
test_score = clf.score(X_test, y_test) 

y_pred = clf.predict(X_test)

# %%
#Trial code 
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.20      0.31        90
#            1       0.88      0.94      0.90      1281
#            2       0.83      0.72      0.77      1547
#            3       0.83      0.93      0.88      2623
#            4       0.72      0.55      0.62       224
#            5       0.69      0.30      0.42       127
#            6       1.00      0.18      0.30        17
#
#     accuracy                           0.84      5909
#    macro avg       0.80      0.54      0.60      5909
# weighted avg       0.83      0.84      0.83      5909

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3,4,5,6])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["M", "K", "G", "F", "A", "B", "O"])

disp.plot(cmap=plt.cm.Blues)
plt.title('$T_{eff}$', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
# plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.savefig('T_eff_weightedknn.png',bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # log (g)

# %%
file_name = 'data_output_logg.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

results_data = {}
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
#Trial code 
k = 230
clf_g = KNeighborsClassifier(n_neighbors = k, weights='distance') 
clf_g.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=230, weights='distance')

# %%
#Trial code 
training_score = clf_g.score(X_train, y_train) 
test_score = clf_g.score(X_test, y_test) 

y_pred = clf_g.predict(X_test)

# %%
#Trial code 
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.80       482
#            1       0.53      0.43      0.47       295
#            2       0.60      0.03      0.05       114
#            3       0.52      0.08      0.13       310
#            4       0.68      0.93      0.79      2935
#            5       0.69      0.46      0.56      1773
#
#     accuracy                           0.69      5909
#    macro avg       0.64      0.45      0.47      5909
# weighted avg       0.68      0.69      0.65      5909

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3,4,5])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["C1", "C2", "C3", "C4", "C5", "C6"])

disp.plot(cmap=plt.cm.Blues)
plt.title('log (g)', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
# plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.savefig('log_g_weightedknn.png',bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # [Fe/H]

# %%
file_name = 'data_output_feh.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
#Trial code 
k = 230
clf_m = KNeighborsClassifier(n_neighbors = k, weights='distance') 
clf_m.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=230, weights='distance')

# %%
#Trial code 
training_score = clf_m.score(X_train, y_train) 
test_score = clf_m.score(X_test, y_test) 

y_pred = clf_m.predict(X_test)

# %%
#Trial code 
from sklearn.metrics import classification_report, confusion_matrix

# print(confusion_matrix(y_test, y_pred,labels=["O, B", "A", "F", "G", "K", "M"]))
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.09      0.16       156
#            1       0.83      0.82      0.82      1690
#            2       0.84      0.95      0.89      3730
#            3       0.74      0.04      0.08       333
#
#     accuracy                           0.84      5909
#    macro avg       0.82      0.47      0.49      5909
# weighted avg       0.83      0.84      0.81      5909

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["XMR",'MR','MP','XMP'])

disp.plot(cmap=plt.cm.Blues)
plt.title('[Fe/H]', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
# plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.savefig('Fe_H_weightedknn.png',bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # With SMOTE

# %% [markdown]
# # T_eff

# %%
file_name = 'data_output_teff.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Apply SMOTE only on the training set
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check new class distribution
print("Class distribution after SMOTE:", Counter(y_train_resampled))
# Out:
# Class distribution after SMOTE: Counter({4: 23605, 3: 23605, 1: 23605, 2: 23605, 5: 23605, 0: 23605, 6: 23605})

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_resampled = scaler.fit_transform(X_train_resampled)
X_test = scaler.transform(X_test)  # Scale test data using same scaler

# %%
# Initialize KNN model
knn = KNeighborsClassifier(n_neighbors=11)  # You can tune 'n_neighbors'

# Train the model
knn.fit(X_train_resampled, y_train_resampled)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
# Predict on test set
y_pred = knn.predict(X_test)

# Evaluate performance
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.96      0.63        90
#            1       0.96      0.90      0.93      1281
#            2       0.83      0.85      0.84      1547
#            3       0.93      0.88      0.90      2623
#            4       0.79      0.94      0.86       224
#            5       0.75      0.92      0.82       127
#            6       0.58      0.82      0.68        17
#
#     accuracy                           0.88      5909
#    macro avg       0.76      0.90      0.81      5909
# weighted avg       0.89      0.88      0.88      5909

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3,4,5,6])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["M", "K", "G", "F", "A", "B", "O"])

disp.plot(cmap=plt.cm.Blues)
plt.title('$T_{eff}$ (After SMOTE)', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
# plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.savefig('t_eff_SMOTE.png',bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # log (g)

# %%
file_name = 'data_output_logg.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

results_data = {}
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Apply SMOTE only on the training set
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check new class distribution
print("Class distribution after SMOTE:", Counter(y_train_resampled))
# Out:
# Class distribution after SMOTE: Counter({4: 26418, 1: 26418, 5: 26418, 0: 26418, 3: 26418, 2: 26418})

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_resampled = scaler.fit_transform(X_train_resampled)
X_test = scaler.transform(X_test)  # Scale test data using same scaler

# %%
# Initialize KNN model
knn = KNeighborsClassifier(n_neighbors=11)  # You can tune 'n_neighbors'

# Train the model
knn.fit(X_train_resampled, y_train_resampled)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
# Predict on test set
y_pred = knn.predict(X_test)

# Evaluate performance
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91       482
#            1       0.67      0.84      0.75       295
#            2       0.36      0.77      0.49       114
#            3       0.32      0.76      0.45       310
#            4       0.82      0.65      0.73      2935
#            5       0.70      0.69      0.70      1773
#
#     accuracy                           0.70      5909
#    macro avg       0.64      0.77      0.67      5909
# weighted avg       0.75      0.70      0.71      5909

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3,4,5])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["C1", "C2", "C3", "C4", "C5", "C6"])

disp.plot(cmap=plt.cm.Blues)
plt.title('log (g) (After SMOTE)', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
# plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.savefig('log_g_SMOTE.png',bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # Fe/H

# %%
file_name = 'data_output_feh.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
# Initialize SMOTE
smote = SMOTE(sampling_strategy='auto', random_state=42)

# Apply SMOTE only on the training set
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Check new class distribution
print("Class distribution after SMOTE:", Counter(y_train_resampled))
# Out:
# Class distribution after SMOTE: Counter({2: 33565, 1: 33565, 0: 33565, 3: 33565})

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_resampled = scaler.fit_transform(X_train_resampled)
X_test = scaler.transform(X_test)  # Scale test data using same scaler

# %%
# Initialize KNN model
knn = KNeighborsClassifier(n_neighbors=11)  # You can tune 'n_neighbors'

# Train the model
knn.fit(X_train_resampled, y_train_resampled)
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
# Predict on test set
y_pred = knn.predict(X_test)

# Evaluate performance
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.52      0.90      0.66       156
#            1       0.88      0.89      0.89      1690
#            2       0.97      0.83      0.89      3730
#            3       0.42      0.91      0.57       333
#
#     accuracy                           0.85      5909
#    macro avg       0.70      0.88      0.75      5909
# weighted avg       0.90      0.85      0.87      5909

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["XMR",'MR','MP','XMP'])

disp.plot(cmap=plt.cm.Blues)
plt.title('[Fe/H] (After SMOTE)', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
# plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.savefig('fe_h_SMOTE.png',bbox_inches='tight',dpi=600)
plt.show()

# %% [markdown]
# # Ensemble Learning

# %%
# T_eff
scores = u.get_baseline_model(X_train_resampled, y_train_resampled, X_test, y_test)
print(scores)
# Out:
# Done!
#   model       auc       mcc       sen      spec
# 0   knn  0.966283  0.834544  0.895249  0.977088
# 1    rf  0.985082  0.898508  0.890095  0.986141
# 2    gb  0.990581  0.881078  0.888181  0.984137
# 3  vote  0.994601  0.892442  0.909007  0.985495

# %%
clf = u.get_model('rf')
clf.fit(X_train_resampled, y_train_resampled)
y_pred = clf.predict(X_test)
print(y_test, y_pred)
# Out:
# [2 3 2 ... 3 0 5] [2 3 2 ... 3 0 5]

# %%
cm = confusion_matrix(y_test, y_pred, labels=[0,1,2,3,4,5,6])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["M", "K", "G", "F", "A", "B", "O"])
disp.plot(cmap=plt.cm.Blues)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.title('$T_{eff}$ (RF Classifier)', fontsize=15, pad=20)
plt.savefig('t_eff_ensem.png',bbox_inches='tight',dpi=600)
plt.show()

# %%
# log (g)
scores = u.get_baseline_model(X_train_resampled, y_train_resampled, X_test, y_test)
print(scores)
# Out:
# Done!
#   model       auc       mcc       sen      spec
# 0   knn  0.912194  0.589784  0.761650  0.932479
# 1    rf  0.956624  0.670908  0.775336  0.944303
# 2    gb  0.936540  0.572306  0.706455  0.929929
# 3  vote  0.957936  0.652786  0.778250  0.942054

# %%
clf = u.get_model('rf')
clf.fit(X_train_resampled, y_train_resampled)
y_pred = clf.predict(X_test)
print(y_test, y_pred)
# Out:
# [0 5 5 ... 5 4 5] [0 5 5 ... 5 5 4]

# %%
cm = confusion_matrix(y_test, y_pred, labels=[0,1,2,3,4,5])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["C1", "C2", "C3", "C4", "C5", "C6"])
disp.plot(cmap=plt.cm.Blues)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.title('log (g) (RF CLassifier)', fontsize=15, pad=20)
plt.savefig('log_g_ensem.png',bbox_inches='tight',dpi=600)
plt.show()

# %%
# [Fe/H]
scores = u.get_baseline_model(X_train_resampled, y_train_resampled, X_test, y_test)
print(scores)
# Out:
# Done!
#   model       auc       mcc       sen      spec
# 0   knn  0.956322  0.781756  0.878938  0.955937
# 1    rf  0.983718  0.848687  0.866508  0.965693
# 2    gb  0.981743  0.778032  0.877749  0.954959
# 3  vote  0.986224  0.825052  0.888913  0.963995

# %%
clf = u.get_model('rf')
clf.fit(X_train_resampled, y_train_resampled)
y_pred = clf.predict(X_test)
print(y_test, y_pred)
# Out:
# [1 1 2 ... 1 1 1] [1 1 2 ... 1 0 1]

# %%
cm = confusion_matrix(y_test, y_pred, labels=[0,1,2,3])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["XMR", "MR", "MP", "XMP"])
disp.plot(cmap=plt.cm.Blues)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.title('[Fe/H] (RF Classifier)', fontsize=15, pad=20)
plt.savefig('fe_h_ensem.png',bbox_inches='tight',dpi=600)
plt.show()
