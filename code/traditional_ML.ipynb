# %%
import utils as u
import pickle as pkl
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split 
from sklearn.neighbors import KNeighborsClassifier   
from sklearn.ensemble import RandomForestClassifier
import seaborn as sns 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# NOTE : The data required for this code is made available at : https://drive.google.com/drive/folders/1Ll5QrfNmgqL4XLM0Of1Tz3mw3noKTuRR?usp=drive_link

# %% [markdown]
# In terms of T_eff

# %%
file_name = 'data_output_teff.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

results_data = {}
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
#Trial code 
# k = 230
# clf = KNeighborsClassifier(n_neighbors = k,weights='distance')
clf = RandomForestClassifier(n_estimators=200, max_depth=5, random_state=0)
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=200, random_state=0)

# %%
#Trial code 
training_score = clf.score(X_train, y_train) 
test_score = clf.score(X_test, y_test) 

y_pred = clf.predict(X_test)

# %%
#Trial code 
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(classification_report(y_test, y_pred))
print("Accuracy_score : ",accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.07      0.12        90
#            1       0.87      0.91      0.89      1281
#            2       0.80      0.75      0.78      1547
#            3       0.86      0.92      0.89      2623
#            4       0.79      0.76      0.77       224
#            5       0.78      0.49      0.60       127
#            6       0.00      0.00      0.00        17
#
#     accuracy                           0.84      5909
#    macro avg       0.71      0.56      0.58      5909
# weighted avg       0.84      0.84      0.84      5909
#
# Accuracy_score :  0.8441360636317482
# c:\Users\kisha\anaconda3\envs\astronomy\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3,4,5,6])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["M", "K", "G", "F", "A", "B", "O"])

disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.show()

# %% [markdown]
# In terms of log(g)

# %%
file_name = 'data_output_logg.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
#Trial code 
# k = 230
# clf_g = KNeighborsClassifier(n_neighbors = k,weights='distance')
clf_g = RandomForestClassifier(n_estimators=200, max_depth=5, random_state=0)
clf_g.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=200, random_state=0)

# %%
#Trial code 
training_score = clf_g.score(X_train, y_train) 
test_score = clf_g.score(X_test, y_test) 

y_pred = clf_g.predict(X_test)

# %%
#Trial code 
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, y_pred))
print("Accuracy_score : ",accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78       482
#            1       0.73      0.20      0.31       295
#            2       0.00      0.00      0.00       114
#            3       0.61      0.10      0.17       310
#            4       0.66      0.92      0.77      2935
#            5       0.70      0.47      0.56      1773
#
#     accuracy                           0.68      5909
#    macro avg       0.58      0.42      0.43      5909
# weighted avg       0.67      0.68      0.64      5909
#
# Accuracy_score :  0.6799796919952614
# c:\Users\kisha\anaconda3\envs\astronomy\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3,4,5])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["C1", "C2", "C3", "C4", "C5", "C6"])

disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.show()

# %% [markdown]
# In terms of [Fe/H]

# %%
file_name = 'data_output_feh.pkl'
n_features = 9

X_train, X_test, y_train, y_test = u.load_pkl_data(file_name)
X_train, X_test = X_train[:,:n_features], X_test[:,:n_features]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (53176, 9) (53176,)
# (5909, 9) (5909,)

# %%
#Trial code 
# k = 230
# clf_m = KNeighborsClassifier(n_neighbors = k,weights='distance')
clf_m = RandomForestClassifier(n_estimators=200, max_depth=5, random_state=0)
clf_m.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=200, random_state=0)

# %%
#Trial code 
training_score = clf_m.score(X_train, y_train) 
test_score = clf_m.score(X_test, y_test) 

y_pred = clf_m.predict(X_test)

# %%
#Trial code 
from sklearn.metrics import classification_report, confusion_matrix

# print(confusion_matrix(y_test, y_pred,labels=["O, B", "A", "F", "G", "K", "M"]))
print(classification_report(y_test, y_pred))
print("Accuracy_score : ",accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       156
#            1       0.84      0.78      0.81      1690
#            2       0.83      0.96      0.89      3730
#            3       0.00      0.00      0.00       333
#
#     accuracy                           0.83      5909
#    macro avg       0.42      0.44      0.42      5909
# weighted avg       0.76      0.83      0.79      5909
#
# Accuracy_score :  0.8297512269419529
# c:\Users\kisha\anaconda3\envs\astronomy\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
cm = confusion_matrix(y_test, y_pred,labels=[0,1,2,3])

disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["XMR",'MR','MP','XMP'])

disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix', fontsize=15, pad=20)
plt.xlabel('Prediction', fontsize=11)
plt.ylabel('Actual', fontsize=11)
plt.gca().xaxis.set_label_position('top')
plt.gca().xaxis.tick_top()
plt.gca().figure.subplots_adjust(bottom=0.2)
plt.gca().figure.text(0.5, 0.05, 'Prediction', ha='center', fontsize=13)

plt.show()
